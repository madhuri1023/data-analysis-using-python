# %%
import pandas as pd
import numpy as np

# %%
d=pd.DataFrame({'Names':['mani','naincy','vishwa'],
                'subject':['DA','ML','PYTHON'],
                'college':['IIT','AEC','ACE']},
                 index=['a','b','c'])
d
# Out:
#     Names subject college
# a    mani      DA     IIT
# b  naincy      ML     AEC
# c  vishwa  PYTHON     ACE

# %%
d['subject']
# Out:
# a        DA
# b        ML
# c    PYTHON
# Name: subject, dtype: object

# %%
d.loc['b']
# Out:
# Names      naincy
# subject        ML
# college       AEC
# Name: b, dtype: object

# %%
d.iloc[2,2]
# Out:
# 'ACE'

# %%
market_df=pd.read_csv('market.csv')
market_df
# Out:
#         Ord_id  Prod_id   Ship_id    Cust_id       Sales  Discount  \
# 0     Ord_5446  Prod_16  SHP_7609  Cust_1818    136.8100      0.01
# 1     Ord_5406  Prod_13  SHP_7549  Cust_1818     42.2700      0.01
# 2     Ord_5446   Prod_4  SHP_7610  Cust_1818   4701.6900      0.00
# 3     Ord_5456   Prod_6  SHP_7625  Cust_1818   2337.8900      0.09
# 4     Ord_5485  Prod_17  SHP_7664  Cust_1818   4233.1500      0.08
# 5     Ord_5446   Prod_6  SHP_7608  Cust_1818    164.0200      0.03
# 6       Ord_31  Prod_12    SHP_41    Cust_26     14.7600      0.01
# 7     Ord_4725   Prod_4  SHP_6593  Cust_1641   3410.1575      0.10
# 8     Ord_4725  Prod_13  SHP_6593  Cust_1641    162.0000      0.01
# 9     Ord_4725   Prod_6  SHP_6593  Cust_1641     57.2200      0.07
# 10    Ord_4743   Prod_2  SHP_6615  Cust_1641   4072.0100      0.01
# 11    Ord_1925   Prod_6  SHP_2637   Cust_708    465.9000      0.05
# 12    Ord_2978  Prod_16  SHP_4112  Cust_1088    305.0500      0.04
# ...

# %%
#head()-prints first rows of data
market_df.head()
# Out:
#      Ord_id  Prod_id   Ship_id    Cust_id    Sales  Discount  Order_Quantity  \
# 0  Ord_5446  Prod_16  SHP_7609  Cust_1818   136.81      0.01              23
# 1  Ord_5406  Prod_13  SHP_7549  Cust_1818    42.27      0.01              13
# 2  Ord_5446   Prod_4  SHP_7610  Cust_1818  4701.69      0.00              26
# 3  Ord_5456   Prod_6  SHP_7625  Cust_1818  2337.89      0.09              43
# 4  Ord_5485  Prod_17  SHP_7664  Cust_1818  4233.15      0.08              35
#
#     Profit  Shipping_Cost  Product_Base_Margin
# 0   -30.51           3.60                 0.56
# 1     4.56           0.93                 0.54
# 2  1148.90           2.50                 0.59
# 3   729.34          14.30                 0.37
# 4  1219.87          26.30                 0.38

# %%
#prints first 7 rows
market_df.head(7)
# Out:
#      Ord_id  Prod_id   Ship_id    Cust_id    Sales  Discount  Order_Quantity  \
# 0  Ord_5446  Prod_16  SHP_7609  Cust_1818   136.81      0.01              23
# 1  Ord_5406  Prod_13  SHP_7549  Cust_1818    42.27      0.01              13
# 2  Ord_5446   Prod_4  SHP_7610  Cust_1818  4701.69      0.00              26
# 3  Ord_5456   Prod_6  SHP_7625  Cust_1818  2337.89      0.09              43
# 4  Ord_5485  Prod_17  SHP_7664  Cust_1818  4233.15      0.08              35
# 5  Ord_5446   Prod_6  SHP_7608  Cust_1818   164.02      0.03              23
# 6    Ord_31  Prod_12    SHP_41    Cust_26    14.76      0.01               5
#
#     Profit  Shipping_Cost  Product_Base_Margin
# 0   -30.51           3.60                 0.56
# 1     4.56           0.93                 0.54
# 2  1148.90           2.50                 0.59
# 3   729.34          14.30                 0.37
# 4  1219.87          26.30                 0.38
# 5   -47.64           6.15                 0.37
# ...

# %%
#tail()-prints the last rows
market_df.tail()
# Out:
#         Ord_id  Prod_id   Ship_id    Cust_id      Sales  Discount  \
# 8394  Ord_5353   Prod_4  SHP_7479  Cust_1798  2841.4395      0.08
# 8395  Ord_5411   Prod_6  SHP_7555  Cust_1798   127.1600      0.10
# 8396  Ord_5388   Prod_6  SHP_7524  Cust_1798   243.0500      0.02
# 8397  Ord_5348  Prod_15  SHP_7469  Cust_1798  3872.8700      0.03
# 8398  Ord_5459   Prod_6  SHP_7628  Cust_1798   603.6900      0.00
#
#       Order_Quantity  Profit  Shipping_Cost  Product_Base_Margin
# 8394              28  374.63           7.69                 0.59
# 8395              20  -74.03           6.92                 0.37
# 8396              39  -70.85           5.35                 0.40
# 8397              23  565.34          30.00                 0.62
# 8398              47  131.39           4.86                 0.38

# %%
#prints last 6 rows
market_df.tail(6)
# Out:
#         Ord_id  Prod_id   Ship_id    Cust_id      Sales  Discount  \
# 8393  Ord_5348   Prod_8  SHP_7470  Cust_1798   356.7200      0.07
# 8394  Ord_5353   Prod_4  SHP_7479  Cust_1798  2841.4395      0.08
# 8395  Ord_5411   Prod_6  SHP_7555  Cust_1798   127.1600      0.10
# 8396  Ord_5388   Prod_6  SHP_7524  Cust_1798   243.0500      0.02
# 8397  Ord_5348  Prod_15  SHP_7469  Cust_1798  3872.8700      0.03
# 8398  Ord_5459   Prod_6  SHP_7628  Cust_1798   603.6900      0.00
#
#       Order_Quantity  Profit  Shipping_Cost  Product_Base_Margin
# 8393               9   12.61           1.99                 0.44
# 8394              28  374.63           7.69                 0.59
# 8395              20  -74.03           6.92                 0.37
# 8396              39  -70.85           5.35                 0.40
# 8397              23  565.34          30.00                 0.62
# 8398              47  131.39           4.86                 0.38

# %%
#sample-prints random rows
market_df.sample()
# Out:
#         Ord_id  Prod_id   Ship_id   Cust_id   Sales  Discount  Order_Quantity  \
# 4761  Ord_2444  Prod_17  SHP_3352  Cust_955  450.28      0.09              25
#
#       Profit  Shipping_Cost  Product_Base_Margin
# 4761  -12.35           8.51                  0.4

# %%
#To print only column names 
market_df.index
# Out:
# RangeIndex(start=0, stop=8399, step=1)

# %%
#to print no of rows and columns
market_df.shape
# Out:
# (8399, 10)

# %%
market_df.shape[0]
# Out:
# 8399

# %%
#info-prints information about file
market_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8399 entries, 0 to 8398
# Data columns (total 10 columns):
# Ord_id                 8399 non-null object
# Prod_id                8399 non-null object
# Ship_id                8399 non-null object
# Cust_id                8399 non-null object
# Sales                  8399 non-null float64
# Discount               8399 non-null float64
# Order_Quantity         8399 non-null int64
# Profit                 8399 non-null float64
# Shipping_Cost          8399 non-null float64
# Product_Base_Margin    8336 non-null float64
# dtypes: float64(5), int64(1), object(4)
# memory usage: 656.2+ KB

# %%
#null-describe all statistical information
market_df.describe()
# Out:
#               Sales     Discount  Order_Quantity        Profit  Shipping_Cost  \
# count   8399.000000  8399.000000     8399.000000   8399.000000    8399.000000
# mean    1775.878179     0.049671       25.571735    181.184424      12.838557
# std     3585.050525     0.031823       14.481071   1196.653371      17.264052
# min        2.240000     0.000000        1.000000 -14140.700000       0.490000
# 25%      143.195000     0.020000       13.000000    -83.315000       3.300000
# 50%      449.420000     0.050000       26.000000     -1.500000       6.070000
# 75%     1709.320000     0.080000       38.000000    162.750000      13.990000
# max    89061.050000     0.250000       50.000000  27220.690000     164.730000
#
#        Product_Base_Margin
# count          8336.000000
# mean              0.512513
# std               0.135589
# min               0.350000
# 25%               0.380000
# 50%               0.520000
# 75%               0.590000
# max               0.850000

# %%
market_df['Sales'].mean() #prints mean
# Out:
# 1775.8781788308156

# %%
market_df['Sales']>30000
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
# 5       False
# 6       False
# 7       False
# 8       False
# 9       False
# 10      False
# 11      False
# 12      False
# 13      False
# 14      False
# 15      False
# 16      False
# 17      False
# 18      False
# 19      False
# 20      False
# 21      False
# 22      False
# 23      False
# 24      False
# 25      False
# 26      False
# 27      False
# 28      False
# 29      False
#         ...
# 8369    False
# 8370    False
# 8371    False
# 8372    False
# 8373    False
# 8374    False
# 8375    False
# 8376    False
# 8377    False
# 8378    False
# 8379    False
# 8380    False
# 8381    False
# 8382    False
# 8383    False
# 8384    False
# 8385    False
# 8386    False
# 8387    False
# 8388    False
# 8389    False
# 8390    False
# 8391    False
# 8392    False
# 8393    False
# 8394    False
# 8395    False
# 8396    False
# 8397    False
# 8398    False
# ...

# %%
market_df[market_df['Sales']>30000]
# Out:
#         Ord_id  Prod_id   Ship_id    Cust_id     Sales  Discount  \
# 1835  Ord_3875  Prod_17  SHP_5370  Cust_1351  41343.21      0.09
# 2349  Ord_2373  Prod_14  SHP_3259   Cust_942  33367.85      0.01
# 2738  Ord_3084  Prod_17  SHP_4279  Cust_1151  89061.05      0.00
# 3784  Ord_2338  Prod_17  SHP_3207   Cust_932  45923.76      0.07
#
#       Order_Quantity    Profit  Shipping_Cost  Product_Base_Margin
# 1835               8   3852.19          24.49                 0.39
# 2349               9   3992.52          24.49                 0.37
# 2738              13  27220.69          24.49                 0.39
# 3784               7    102.61          24.49                 0.39

# %%
market_df[(market_df['Sales']>30000) & (market_df['Sales']<35000)]
# Out:
#         Ord_id  Prod_id   Ship_id   Cust_id     Sales  Discount  \
# 2349  Ord_2373  Prod_14  SHP_3259  Cust_942  33367.85      0.01
#
#       Order_Quantity   Profit  Shipping_Cost  Product_Base_Margin
# 2349               9  3992.52          24.49                 0.37

# %%
market_df[market_df['Prod_id']=='Prod_16']
# Out:
#         Ord_id  Prod_id   Ship_id    Cust_id    Sales  Discount  \
# 0     Ord_5446  Prod_16  SHP_7609  Cust_1818   136.81      0.01
# 12    Ord_2978  Prod_16  SHP_4112  Cust_1088   305.05      0.04
# 93    Ord_5484  Prod_16  SHP_7663  Cust_1820   322.82      0.05
# 214   Ord_3730  Prod_16  SHP_5175  Cust_1314   459.08      0.04
# 280   Ord_4143  Prod_16  SHP_5771  Cust_1417   207.21      0.06
# 304   Ord_4796  Prod_16  SHP_6686  Cust_1659    95.09      0.09
# 312   Ord_1854  Prod_16  SHP_2548   Cust_727   182.47      0.05
# 327   Ord_4506  Prod_16  SHP_6273  Cust_1544    92.02      0.07
# 348   Ord_4080  Prod_16  SHP_5688  Cust_1388   666.40      0.00
# 393   Ord_1551  Prod_16  SHP_2145   Cust_531   184.77      0.00
# 405   Ord_1579  Prod_16  SHP_2178   Cust_566   139.37      0.04
# 454   Ord_1429  Prod_16  SHP_1976   Cust_510   539.06      0.05
# 471   Ord_2471  Prod_16  SHP_3386   Cust_965    90.93      0.05
# 588   Ord_2873  Prod_16  SHP_3957  Cust_1052   138.55      0.03
# ...

# %%
len(market_df[market_df['Prod_id']=='Prod_16'])
# Out:
# 144

# %%
market_df[(market_df['Prod_id']=='Prod_16')&(market_df['Sales']>20000)]
# Out:
#         Ord_id  Prod_id   Ship_id    Cust_id     Sales  Discount  \
# 3786  Ord_4806  Prod_16  SHP_6699  Cust_1575  23516.31      0.09
#
#       Order_Quantity   Profit  Shipping_Cost  Product_Base_Margin
# 3786              29  1094.74          24.49                 0.83

# %%
#isnull()-prints if there are non-null values
market_df.isnull()
# Out:
#       Ord_id  Prod_id  Ship_id  Cust_id  Sales  Discount  Order_Quantity  \
# 0      False    False    False    False  False     False           False
# 1      False    False    False    False  False     False           False
# 2      False    False    False    False  False     False           False
# 3      False    False    False    False  False     False           False
# 4      False    False    False    False  False     False           False
# 5      False    False    False    False  False     False           False
# 6      False    False    False    False  False     False           False
# 7      False    False    False    False  False     False           False
# 8      False    False    False    False  False     False           False
# 9      False    False    False    False  False     False           False
# 10     False    False    False    False  False     False           False
# 11     False    False    False    False  False     False           False
# ...

# %%
market_df.isnull().sum()
# Out:
# Ord_id                  0
# Prod_id                 0
# Ship_id                 0
# Cust_id                 0
# Sales                   0
# Discount                0
# Order_Quantity          0
# Profit                  0
# Shipping_Cost           0
# Product_Base_Margin    63
# dtype: int64

# %%
market_df['Product_Base_Margin'].mean()
# Out:
# 0.5125131957773527

# %%
market_df['Product_Base_Margin'].fillna(0.5125,inplace=True)

# %%
market_df.isnull().sum()
# Out:
# Ord_id                 0
# Prod_id                0
# Ship_id                0
# Cust_id                0
# Sales                  0
# Discount               0
# Order_Quantity         0
# Profit                 0
# Shipping_Cost          0
# Product_Base_Margin    0
# dtype: int64

# %%
d=pd.DataFrame({'student':['mani','mani','vishwa'],
                'branch':['IT','IT','CSE'],
                'id':['101','101','103']})
                
d
# Out:
#   student branch   id
# 0    mani     IT  101
# 1    mani     IT  101
# 2  vishwa    CSE  103

# %%
#to identify duplicate values and printd boolean values
d.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# dtype: bool

# %%
#prints duplicate value with index
d[d.duplicated()]
# Out:
#   student branch   id
# 1    mani     IT  101

# %%
#drop-to remove duplicate 
d.drop_duplicates()
# Out:
#   student branch   id
# 0    mani     IT  101
# 2  vishwa    CSE  103

# %%
#to remove in original data
d.drop_duplicates(inplace=True)
d
# Out:
#   student branch   id
# 0    mani     IT  101
# 2  vishwa    CSE  103

# %%
d.isnull()
# Out:
#    student  branch     id
# 0    False   False  False
# 2    False   False  False

# %%
#TASK 
import numpy as np
import pandas as pd
d=({'College':['AEC','ACET',np.NaN,'AEC'],
   'Strength':[5000,np.NaN,2500,3899],
   'Placed':['4000',3000,2000,np.NaN],
   'Trained':[np.NaN,6000,5000,3500]})
d
# Out:
# {'College': ['AEC', 'ACET', nan, 'AEC'],
#  'Strength': [5000, nan, 2500, 3899],
#  'Placed': ['4000', 3000, 2000, nan],
#  'Trained': [nan, 6000, 5000, 3500]}

# %%
x=pd.DataFrame(d)
x
# Out:
#   College  Strength Placed  Trained
# 0     AEC    5000.0   4000      NaN
# 1    ACET       NaN   3000   6000.0
# 2     NaN    2500.0   2000   5000.0
# 3     AEC    3899.0    NaN   3500.0

# %%
x['College'].value_counts()
# Out:
# AEC     3
# ACET    1
# Name: College, dtype: int64

# %%
x['College'].fillna('AEC',inplace=True)
x
# Out:
#   College  Strength Placed  Trained
# 0     AEC    5000.0   4000      NaN
# 1    ACET       NaN   3000   6000.0
# 2     AEC    2500.0   2000   5000.0
# 3     AEC    3899.0    NaN   3500.0

# %%
x['Strength'].bfill()
# Out:
# 0    5000.0
# 1    2500.0
# 2    2500.0
# 3    3899.0
# Name: Strength, dtype: float64

# %%
x['Strength'].bfill(inplace=True)
x
# Out:
#   College  Strength Placed  Trained
# 0     AEC    5000.0   4000      NaN
# 1    ACET    2500.0   3000   6000.0
# 2     AEC    2500.0   2000   5000.0
# 3     AEC    3899.0    NaN   3500.0

# %%
x['Placed'].ffill()
# Out:
# 0    4000
# 1    3000
# 2    2000
# 3    2000
# Name: Placed, dtype: object

# %%
x['Placed'].ffill(inplace=True)
x
# Out:
#   College  Strength Placed  Trained
# 0     AEC    5000.0   4000      NaN
# 1    ACET    2500.0   3000   6000.0
# 2     AEC    2500.0   2000   5000.0
# 3     AEC    3899.0   2000   3500.0

# %%
x['Trained'].mean()
# Out:
# 4833.333333333333

# %%
x['Trained'].fillna(4833.33,inplace=True)
x
# Out:
#   College  Strength Placed  Trained
# 0     AEC    5000.0   4000  4833.33
# 1    ACET    2500.0   3000  6000.00
# 2     AEC    2500.0   2000  5000.00
# 3     AEC    3899.0   2000  3500.00

# %%
x.isnull().sum()
# Out:
# College     0
# Strength    0
# Placed      0
# Trained     0
# dtype: int64

# %%
#TASK HEART DISEASE
hd=pd.read_csv('heart_disease.csv')
hd
# Out:
#      Unnamed: 0  Age  Sex     ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  \
# 0             1   63    1       typical     145   233    1        2    150
# 1             2   67    1  asymptomatic     160   286    0        2    108
# 2             3   67    1  asymptomatic     120   229    0        2    129
# 3             4   37    1    nonanginal     130   250    0        0    187
# 4             5   41    0    nontypical     130   204    0        2    172
# 5             6   56    1    nontypical     120   236    0        0    178
# 6             7   62    0  asymptomatic     140   268    0        2    160
# 7             8   57    0  asymptomatic     120   354    0        0    163
# 8             9   63    1  asymptomatic     130   254    0        2    147
# 9            10   53    1  asymptomatic     140   203    1        2    155
# 10           11   57    1  asymptomatic     140   192    0        0    148
# ...

# %%
#TASK TITANIC
t=pd.read_csv('titanic.csv')
t
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
t.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
t.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
t.sample()
# Out:
#      PassengerId  Survived  Pclass                        Name   Sex  Age  \
# 788          789         1       3  Dean, Master. Bertram Vere  male  1.0
#
#      SibSp  Parch     Ticket    Fare Cabin Embarked
# 788      1      2  C.A. 2315  20.575   NaN        S

# %%
t.shape
# Out:
# (891, 12)

# %%
t.index
# Out:
# RangeIndex(start=0, stop=8399, step=1)

# %%
t.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.6+ KB

# %%
t.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
t.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
t.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
t['Age'].value_counts()
# Out:
# 24.00    30
# 22.00    27
# 18.00    26
# 19.00    25
# 30.00    25
# 28.00    25
# 21.00    24
# 25.00    23
# 36.00    22
# 29.00    20
# 32.00    18
# 27.00    18
# 35.00    18
# 26.00    18
# 16.00    17
# 31.00    17
# 20.00    15
# 33.00    15
# 23.00    15
# 34.00    15
# 39.00    14
# 17.00    13
# 42.00    13
# 40.00    13
# 45.00    12
# 38.00    11
# 50.00    10
# 2.00     10
# 4.00     10
# 47.00     9
#          ..
# 71.00     2
# 59.00     2
# 63.00     2
# 0.83      2
# 30.50     2
# 70.00     2
# 57.00     2
# 0.75      2
# 13.00     2
# 10.00     2
# 64.00     2
# 40.50     2
# 32.50     2
# 45.50     2
# 20.50     1
# 24.50     1
# 0.67      1
# 14.50     1
# 0.92      1
# 74.00     1
# 34.50     1
# 80.00     1
# 12.00     1
# 36.50     1
# 53.00     1
# 55.50     1
# 70.50     1
# 66.00     1
# 23.50     1
# 0.42      1
# Name: Age, Length: 88, dtype: int64

# %%
t['Age'].mean()
# Out:
# 29.69911764705882

# %%
t['Age'].fillna(30,inplace=True)
t
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
t['Cabin'].value_counts().max()
# Out:
# 4

# %%
t['Cabin'].fillna('G6',inplace=True)
t
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
#prints numeric columns with 0 and 1
pd.get_dummies(t['Embarked'])
# Out:
#      0  1
# 0    0  1
# 1    1  0
# 2    0  1
# 3    0  1
# 4    0  1
# 5    0  1
# 6    0  1
# 7    0  1
# 8    0  1
# 9    1  0
# 10   0  1
# 11   0  1
# 12   0  1
# 13   0  1
# 14   0  1
# 15   0  1
# 16   0  1
# 17   0  1
# 18   0  1
# 19   1  0
# 20   0  1
# 21   0  1
# 22   0  1
# 23   0  1
# 24   0  1
# 25   0  1
# 26   1  0
# 27   0  1
# 28   0  1
# 29   0  1
# ..  .. ..
# 861  0  1
# 862  0  1
# 863  0  1
# 864  0  1
# 865  0  1
# 866  1  0
# 867  0  1
# 868  0  1
# 869  0  1
# 870  0  1
# 871  0  1
# 872  0  1
# 873  0  1
# 874  1  0
# 875  1  0
# 876  0  1
# 877  0  1
# 878  0  1
# 879  1  0
# 880  0  1
# 881  0  1
# 882  0  1
# 883  0  1
# 884  0  1
# 885  0  1
# 886  0  1
# 887  0  1
# 888  0  1
# 889  1  0
# 890  0  1
#
# [891 rows x 2 columns]

# %%
#prints numeric columns with 0 and 1
t['Embarked']=pd.get_dummies(t['Embarked'])
t
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
#prints differentiate with 0 and 1 within a single column
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
t['Embarked']=le.fit_transform(t['Embarked'])
t
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
#TASK HEART DISEASE
hd=pd.read_csv('heart_disease.csv')
hd
# Out:
#      Unnamed: 0  Age  Sex     ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  \
# 0             1   63    1       typical     145   233    1        2    150
# 1             2   67    1  asymptomatic     160   286    0        2    108
# 2             3   67    1  asymptomatic     120   229    0        2    129
# 3             4   37    1    nonanginal     130   250    0        0    187
# 4             5   41    0    nontypical     130   204    0        2    172
# 5             6   56    1    nontypical     120   236    0        0    178
# 6             7   62    0  asymptomatic     140   268    0        2    160
# 7             8   57    0  asymptomatic     120   354    0        0    163
# 8             9   63    1  asymptomatic     130   254    0        2    147
# 9            10   53    1  asymptomatic     140   203    1        2    155
# 10           11   57    1  asymptomatic     140   192    0        0    148
# ...

# %%
hd.isnull().sum()
# Out:
# Unnamed: 0    0
# Age           0
# Sex           0
# ChestPain     0
# RestBP        0
# Chol          0
# Fbs           0
# RestECG       0
# MaxHR         0
# ExAng         0
# Oldpeak       0
# Slope         0
# Ca            4
# Thal          2
# AHD           0
# dtype: int64

# %%
hd.drop('Unnamed: 0',axis=1,inplace=True)

# %%
hd
# Out:
#      Age  Sex     ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  ExAng  \
# 0     63    1       typical     145   233    1        2    150      0
# 1     67    1  asymptomatic     160   286    0        2    108      1
# 2     67    1  asymptomatic     120   229    0        2    129      1
# 3     37    1    nonanginal     130   250    0        0    187      0
# 4     41    0    nontypical     130   204    0        2    172      0
# 5     56    1    nontypical     120   236    0        0    178      0
# 6     62    0  asymptomatic     140   268    0        2    160      0
# 7     57    0  asymptomatic     120   354    0        0    163      1
# 8     63    1  asymptomatic     130   254    0        2    147      0
# 9     53    1  asymptomatic     140   203    1        2    155      1
# 10    57    1  asymptomatic     140   192    0        0    148      0
# 11    56    0    nontypical     140   294    0        2    153      0
# ...

# %%
hd['Ca'].value_counts()
# Out:
# 0.0    176
# 1.0     65
# 2.0     38
# 3.0     20
# Name: Ca, dtype: int64

# %%
hd['Ca'].fillna('0.0',inplace=True)

# %%
hd['Thal'].value_counts()
# Out:
# normal        166
# reversable    117
# fixed          18
# Name: Thal, dtype: int64

# %%
hd['Thal'].fillna('normal',inplace=True)

# %%
hd.isnull().sum()
# Out:
# Age          0
# Sex          0
# ChestPain    0
# RestBP       0
# Chol         0
# Fbs          0
# RestECG      0
# MaxHR        0
# ExAng        0
# Oldpeak      0
# Slope        0
# Ca           0
# Thal         0
# AHD          0
# dtype: int64

# %%
hd['AHD'].
